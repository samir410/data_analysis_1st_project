# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv(
    'D:/dataanlysis/pet_project/Data/weather_data.csv',
    index_col=0,
    parse_dates=True
)

# %%
df.head()
# Out:
#                      Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# Date/Time
# 2012-01-01 00:00:00    -1.8              -3.9         86                4
# 2012-01-01 01:00:00    -1.8              -3.7         87                4
# 2012-01-01 02:00:00    -1.8              -3.4         89                7
# 2012-01-01 03:00:00    -1.5              -3.2         88                6
# 2012-01-01 04:00:00    -1.5              -3.3         88                7
#
#                      Visibility_km  Press_kPa               Weather
# Date/Time
# 2012-01-01 00:00:00            8.0     101.24                   Fog
# 2012-01-01 01:00:00            8.0     101.24                   Fog
# 2012-01-01 02:00:00            4.0     101.26  Freezing Drizzle,Fog
# 2012-01-01 03:00:00            4.0     101.27  Freezing Drizzle,Fog
# 2012-01-01 04:00:00            4.8     101.23                   Fog

# %%
df.info
# Out:
# <bound method DataFrame.info of                      Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# Date/Time
# 2012-01-01 00:00:00    -1.8              -3.9         86                4
# 2012-01-01 01:00:00    -1.8              -3.7         87                4
# 2012-01-01 02:00:00    -1.8              -3.4         89                7
# 2012-01-01 03:00:00    -1.5              -3.2         88                6
# 2012-01-01 04:00:00    -1.5              -3.3         88                7
# ...                     ...               ...        ...              ...
# 2012-12-31 19:00:00     0.1              -2.7         81               30
# 2012-12-31 20:00:00     0.2              -2.4         83               24
# 2012-12-31 21:00:00    -0.5              -1.5         93               28
# 2012-12-31 22:00:00    -0.2              -1.8         89               28
# 2012-12-31 23:00:00     0.0              -2.1         86               30
#
# ...

# %%
df.shape
df.head()
# Out:
#                      Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# Date/Time
# 2012-01-01 00:00:00    -1.8              -3.9         86                4
# 2012-01-01 01:00:00    -1.8              -3.7         87                4
# 2012-01-01 02:00:00    -1.8              -3.4         89                7
# 2012-01-01 03:00:00    -1.5              -3.2         88                6
# 2012-01-01 04:00:00    -1.5              -3.3         88                7
#
#                      Visibility_km  Press_kPa               Weather
# Date/Time
# 2012-01-01 00:00:00            8.0     101.24                   Fog
# 2012-01-01 01:00:00            8.0     101.24                   Fog
# 2012-01-01 02:00:00            4.0     101.26  Freezing Drizzle,Fog
# 2012-01-01 03:00:00            4.0     101.27  Freezing Drizzle,Fog
# 2012-01-01 04:00:00            4.8     101.23                   Fog

# %% [markdown]
# # Find all the unique "wind spreed" values in the data

# %%
a=df['Wind Speed_km/h']
a.duplicated()
# Out:
# Date/Time
# 2012-01-01 00:00:00    False
# 2012-01-01 01:00:00     True
# 2012-01-01 02:00:00    False
# 2012-01-01 03:00:00    False
# 2012-01-01 04:00:00     True
#                        ...
# 2012-12-31 19:00:00     True
# 2012-12-31 20:00:00     True
# 2012-12-31 21:00:00     True
# 2012-12-31 22:00:00     True
# 2012-12-31 23:00:00     True
# Name: Wind Speed_km/h, Length: 8784, dtype: bool

# %%
b=a.unique()

# %%
b.copy()
# Out:
# array([ 4,  7,  6,  9, 15, 13, 20, 22, 19, 24, 30, 35, 39, 32, 33, 26, 44,
#        43, 48, 37, 28, 17, 11,  0, 83, 70, 57, 46, 41, 52, 50, 63, 54,  2],
#       dtype=int64)

# %%
a.plot(kind='density', figsize=(14,8)) # kde
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# # Find the number of times wheather was actully clear?

# %%
df.head()
# Out:
#                      Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# Date/Time
# 2012-01-01 00:00:00    -1.8              -3.9         86                4
# 2012-01-01 01:00:00    -1.8              -3.7         87                4
# 2012-01-01 02:00:00    -1.8              -3.4         89                7
# 2012-01-01 03:00:00    -1.5              -3.2         88                6
# 2012-01-01 04:00:00    -1.5              -3.3         88                7
#
#                      Visibility_km  Press_kPa               Weather
# Date/Time
# 2012-01-01 00:00:00            8.0     101.24                   Fog
# 2012-01-01 01:00:00            8.0     101.24                   Fog
# 2012-01-01 02:00:00            4.0     101.26  Freezing Drizzle,Fog
# 2012-01-01 03:00:00            4.0     101.27  Freezing Drizzle,Fog
# 2012-01-01 04:00:00            4.8     101.23                   Fog

# %%
df.head(20)
# Out:
#                      Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# Date/Time
# 2012-01-01 00:00:00    -1.8              -3.9         86                4
# 2012-01-01 01:00:00    -1.8              -3.7         87                4
# 2012-01-01 02:00:00    -1.8              -3.4         89                7
# 2012-01-01 03:00:00    -1.5              -3.2         88                6
# 2012-01-01 04:00:00    -1.5              -3.3         88                7
# 2012-01-01 05:00:00    -1.4              -3.3         87                9
# 2012-01-01 06:00:00    -1.5              -3.1         89                7
# 2012-01-01 07:00:00    -1.4              -3.6         85                7
# 2012-01-01 08:00:00    -1.4              -3.6         85                9
# 2012-01-01 09:00:00    -1.3              -3.1         88               15
# 2012-01-01 10:00:00    -1.0              -2.3         91                9
# ...

# %%
a=df['Weather'].value_counts()
a.Clear
# Out:
# 306

# %%
a.plot(kind='bar', figsize=(10,6))
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Number of times the wind was exacly 4 km/h

# %%
df.head()
df
# Out:
#                      Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# Date/Time
# 2012-01-01 00:00:00    -1.8              -3.9         86                4
# 2012-01-01 01:00:00    -1.8              -3.7         87                4
# 2012-01-01 02:00:00    -1.8              -3.4         89                7
# 2012-01-01 03:00:00    -1.5              -3.2         88                6
# 2012-01-01 04:00:00    -1.5              -3.3         88                7
#
#                      Visibility_km  Press_kPa               Weather
# Date/Time
# 2012-01-01 00:00:00            8.0     101.24                   Fog
# 2012-01-01 01:00:00            8.0     101.24                   Fog
# 2012-01-01 02:00:00            4.0     101.26  Freezing Drizzle,Fog
# 2012-01-01 03:00:00            4.0     101.27  Freezing Drizzle,Fog
# 2012-01-01 04:00:00            4.8     101.23                   Fog

# %%
x=df[df['Wind Speed_km/h']==4]
x.shape
# Out:
# (474, 7)

# %%
# Find out null value
df.isnull().sum()
# Out:
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %%
#mean of visibilaty
df['Visibility_km'].mean()
# Out:
# 27.66444672131151

# %% [markdown]
# # Findout all instance of wind spreed avobe 24

# %%
ws=df[(df['Wind Speed_km/h']>24) & (df.Visibility_km==25)]
ws
# Out:
#                      Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# Date/Time
# 2012-01-01 23:00:00     5.3               2.0         79               30
# 2012-01-02 00:00:00     5.2               1.5         77               35
# 2012-01-02 01:00:00     4.6               0.0         72               39
# 2012-01-02 02:00:00     3.9              -0.9         71               32
# 2012-01-02 03:00:00     3.7              -1.5         69               33
# ...                     ...               ...        ...              ...
# 2012-12-28 17:00:00    -8.6             -12.0         76               26
# 2012-12-30 17:00:00   -12.1             -15.8         74               28
# 2012-12-30 19:00:00   -13.4             -16.5         77               26
# 2012-12-30 23:00:00   -12.1             -15.1         78               28
# 2012-12-31 00:00:00   -11.1             -14.4         77               26
#
#                      Visibility_km  Press_kPa        Weather
# ...

# %% [markdown]
# # What is the mean value of each coloum against Weather Conditions

# %%
df.head()
# Out:
#                      Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# Date/Time
# 2012-01-01 00:00:00    -1.8              -3.9         86                4
# 2012-01-01 01:00:00    -1.8              -3.7         87                4
# 2012-01-01 02:00:00    -1.8              -3.4         89                7
# 2012-01-01 03:00:00    -1.5              -3.2         88                6
# 2012-01-01 04:00:00    -1.5              -3.3         88                7
#
#                      Visibility_km  Press_kPa               Weather
# Date/Time
# 2012-01-01 00:00:00            8.0     101.24                   Fog
# 2012-01-01 01:00:00            8.0     101.24                   Fog
# 2012-01-01 02:00:00            4.0     101.26  Freezing Drizzle,Fog
# 2012-01-01 03:00:00            4.0     101.27  Freezing Drizzle,Fog
# 2012-01-01 04:00:00            4.8     101.23                   Fog

# %%
df.groupby('Weather').mean()
# Out:
#                                             Temp_C  Dew Point Temp_C  \
# Weather
# Clear                                     6.825716          0.089367
# Cloudy                                    7.970544          2.375810
# Drizzle                                   7.353659          5.504878
# Drizzle,Fog                               8.067500          7.033750
# Drizzle,Ice Pellets,Fog                   0.400000         -0.700000
# Drizzle,Snow                              1.050000          0.150000
# Drizzle,Snow,Fog                          0.693333          0.120000
# Fog                                       4.303333          3.159333
# Freezing Drizzle                         -5.657143         -8.000000
# Freezing Drizzle,Fog                     -2.533333         -4.183333
# Freezing Drizzle,Haze                    -5.433333         -8.000000
# Freezing Drizzle,Snow                    -5.109091         -7.072727
# ...

# %% [markdown]
# # Show all records weaher condition where weather is fog

# %%
a=df[df['Weather']=='Fog']
a
# Out:
#                      Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# Date/Time
# 2012-01-01 00:00:00    -1.8              -3.9         86                4
# 2012-01-01 01:00:00    -1.8              -3.7         87                4
# 2012-01-01 04:00:00    -1.5              -3.3         88                7
# 2012-01-01 05:00:00    -1.4              -3.3         87                9
# 2012-01-01 06:00:00    -1.5              -3.1         89                7
# ...                     ...               ...        ...              ...
# 2012-12-29 04:00:00   -16.0             -17.2         90                6
# 2012-12-29 05:00:00   -14.8             -15.9         91                4
# 2012-12-29 06:00:00   -13.8             -15.3         88                4
# 2012-12-29 07:00:00   -14.8             -16.4         88                7
# 2012-12-29 10:00:00   -12.0             -13.3         90                7
#
#                      Visibility_km  Press_kPa Weather
# Date/Time
# ...

# %% [markdown]
# # Find all the instance where Weather is Clear and Visibilaty  avobe 40

# %%
df.head()
# Out:
#                      Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# Date/Time
# 2012-01-01 00:00:00    -1.8              -3.9         86                4
# 2012-01-01 01:00:00    -1.8              -3.7         87                4
# 2012-01-01 02:00:00    -1.8              -3.4         89                7
# 2012-01-01 03:00:00    -1.5              -3.2         88                6
# 2012-01-01 04:00:00    -1.5              -3.3         88                7
#
#                      Visibility_km  Press_kPa               Weather
# Date/Time
# 2012-01-01 00:00:00            8.0     101.24                   Fog
# 2012-01-01 01:00:00            8.0     101.24                   Fog
# 2012-01-01 02:00:00            4.0     101.26  Freezing Drizzle,Fog
# 2012-01-01 03:00:00            4.0     101.27  Freezing Drizzle,Fog
# 2012-01-01 04:00:00            4.8     101.23                   Fog

# %%
data= df[(df['Weather']=='Clear') | (df['Visibility_km']>40)]
data
# Out:
#                      Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# Date/Time
# 2012-01-03 19:00:00   -16.9             -24.8         50               24
# 2012-01-05 10:00:00    -6.0             -10.0         73               17
# 2012-01-05 11:00:00    -5.6             -10.2         70               22
# 2012-01-05 12:00:00    -4.7              -9.6         69               20
# 2012-01-05 13:00:00    -4.4              -9.7         66               26
# ...                     ...               ...        ...              ...
# 2012-12-30 13:00:00   -12.4             -16.2         73               37
# 2012-12-30 14:00:00   -11.8             -16.1         70               37
# 2012-12-30 15:00:00   -11.3             -15.6         70               32
# 2012-12-30 16:00:00   -11.4             -15.5         72               26
# 2012-12-30 20:00:00   -13.8             -16.5         80               24
#
#                      Visibility_km  Press_kPa        Weather
# ...
